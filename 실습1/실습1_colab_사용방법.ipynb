# %% [markdown]
# # 코랩 기본 사용법

# %% [markdown]
# ## 생성

# %% [markdown]
# * 코랩을 한 번도 사용해본 적이 없다면 코랩 어플리케이션을 추가하여야 함
# * 구글 드라이브에서 배경에 오른쪽 클릭을 하면 위와 같은 탭이 생성
# * 여기서 더보기를 클릭하여 '연결할 앱 더보기'를 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Google Colaboratory가 검색되면 이를 설치

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 런타임 (환경 설정)

# %% [markdown]
# * 런타임 유형 변경 선택후 하드웨어 가속기 선택 가능
# * 딥러닝 시에는 GPU를 사용하는 것이 권장됨

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# * '런타임 연결 해제 및 삭제'를 눌러 초기화 후 다시 실행할 수 있음

# %% [markdown]
# ## 파일 저장

# %% [markdown]
# * '저장'을 선택하여 ipynb 주피터 노트북 형태로 구글 드라이브에 저장 (저장을 누르지 않아도 수시로 자동 저장이 됨)
# * 업데이트 기록을 선택하면 지난 노트북 버전들이 시간대별로 저장되어 있음. 이전 버젼을 선택하여 다시 복원할 수 있음
# * '다운로드' 탭을 눌러 로컬에 파일 저장 가능

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 공유

# %% [markdown]
# * 우측 상단의 공유를 눌러 공유 가능

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 사용자 및 그룹 추가에서 구글 이메일을 추가하여 노트에 대한 접근 권한을 줄 수 있음
# * 링크 복사를 선택하여 링크로 노트북을 공유할 수 있음. 단, 링크가 있는 모든 사용자로 변경을 선택하여야지 링크를 가진 모든 사람이 노트북에 접근을 얻게 됨.

# %% [markdown]
# ## 목차

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 왼쪽 탭에서 첫번째 아이콘을 누르면 목차를 볼 수 있음

# %% [markdown]
# ## 파일

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 왼쪽 탭에서 마지막 아이콘을 누르면 연결된 파일 목록을 볼 수 있음

# %% [markdown]
# ## 단축키

# %% [markdown]
# * 도구 탭에서 단축키를 선택하여 단축기를 설정할 수 있음

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 기본 단축키:
#
# * shift + enter: 셀을 실행
# * ctrl + M + b: 코드 셀을 추가
# * ctrl + shift + h: 셀에서 문자/숫자 찾아 다른 문자/숫자로 대체

# %% [markdown]
# ## 셀

# %% [markdown]
# * 셀에는 2가지 종류가 존재: 코드 셀, 텍스트 셀
# * 코드 셀에서는 코드를 실행할 수 있음
# * 텍스트 셀에서는 텍스트를 입력할 수 있음
# * 기존 텍스트 셀 또는 코드 셀의 상단 또는 하단에 커서를 들이밀면 '+코드', '+텍스트' 버튼이 생김. 해당 버튼을 눌러 셀을 추가할 수 있음

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 코드 셀 예시

# %% [markdown]
# 텍스트 셀 예시

# %% [markdown]
# * 셀의 우측 상단에는 명령 아이콘들이 나열되어 있음
# * 화살표 아이콘을 눌러 셀의 위치를 조정
# * 마지막에서 두번째 아이콘을 눌러 셀 삭제 가능

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 그 외에도 셀에 오른쪽 클릭을 하여 셀을 삭제, 복사, 잘라내기 등의 작업을 진행할 수 있음
# * 또는 일상적으로 사용하는 단축기들(예. ctrl+c, ctrl+v,ctrl+x 등)을 사용할 수 있음
